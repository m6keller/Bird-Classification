# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../metadata/birds.csv")
df.head(50)
# Out:
#     class id                      filepaths           labels data set
# 0        0.0  train/ABBOTTS BABBLER/001.jpg  ABBOTTS BABBLER    train  \
# 1        0.0  train/ABBOTTS BABBLER/007.jpg  ABBOTTS BABBLER    train
# 2        0.0  train/ABBOTTS BABBLER/008.jpg  ABBOTTS BABBLER    train
# 3        0.0  train/ABBOTTS BABBLER/009.jpg  ABBOTTS BABBLER    train
# 4        0.0  train/ABBOTTS BABBLER/002.jpg  ABBOTTS BABBLER    train
# 5        0.0  train/ABBOTTS BABBLER/003.jpg  ABBOTTS BABBLER    train
# 6        0.0  train/ABBOTTS BABBLER/004.jpg  ABBOTTS BABBLER    train
# 7        0.0  train/ABBOTTS BABBLER/005.jpg  ABBOTTS BABBLER    train
# 8        0.0  train/ABBOTTS BABBLER/006.jpg  ABBOTTS BABBLER    train
# 9        0.0  train/ABBOTTS BABBLER/010.jpg  ABBOTTS BABBLER    train
# 10       0.0  train/ABBOTTS BABBLER/016.jpg  ABBOTTS BABBLER    train
# 11       0.0  train/ABBOTTS BABBLER/017.jpg  ABBOTTS BABBLER    train
# ...

# %%
df.describe()
# Out:
#            class id
# count  89885.000000
# mean     265.062168
# std      152.288939
# min        0.000000
# 25%      133.000000
# 50%      267.000000
# 75%      397.000000
# max      524.000000

# %%
df["class id"].groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df["class id"].groupby()
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/series.py:2060, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2057 from pandas.core.groupby.generic import SeriesGroupBy
#    2059 if level is None and by is None:
# -> 2060     raise TypeError("You have to supply one of 'by' and 'level'")
#    2061 if not as_index:
#    2062     raise TypeError("as_index=False only valid with DataFrame")
#
# TypeError: You have to supply one of 'by' and 'level'

# %%
df["class id"].value_counts()
# Out:
# class id
# 426.0    273
# 286.0    258
# 181.0    243
# 367.0    243
# 40.0     230
#         ...
# 357.0    140
# 445.0    140
# 375.0    140
# 211.0    140
# 408.0    140
# Name: count, Length: 525, dtype: int64

# %%
plt.hist(df["class id"].value_counts())
# Out:
# (array([108., 141., 144.,  47.,  46.,  29.,   6.,   2.,   1.,   1.]),
#  array([140. , 153.3, 166.6, 179.9, 193.2, 206.5, 219.8, 233.1, 246.4,
#         259.7, 273. ]),
#  <BarContainer object of 10 artists>)

# %%
df["class id"].nunique()
# Out:
# 525

# %%
df.shape
# Out:
# (89885, 5)

# %%
df.shape[0]
# Out:
# 89885
